# %% [markdown]
# # 혈압 예측 모델 설계

# %% [markdown]
# ## Load modules

# %%
import numpy as np

print("NumPy Version :{}".format(np.__version__))
# Out:
# NumPy Version :2.0.2

# %% [markdown]
# ## Input and Label

# %%
# Input(AGE) and Labels(BP)
x_input = np.array([25,25,25,35,35,35,45,45,45,55,55,55,65,65,65,73,73,73], dtype= np.float32)
labels = np.array([118,125,130,118,126,123,120,124,130,122,125,130,127,130,130,125.5,130,138], dtype= np.float32)

# Weights
W = np.random.normal()
B = np.random.normal()

# %% [markdown]
# ## Hypothesis : Linear Equation
# >### $h(x) = wx + b$

# %%
# Hypothesis : Linear Function
def Hypothesis(x):
    return W*x + B

# %% [markdown]
# ## Cost Function : Mean Squared Error (MSE)
# >### cost(w, b) = $\frac{1}{m} \sum_{i=1}^{m}(h(x_{i})-y_{i})^{2}$

# %%
# Cost : Mean Squared Error
def Cost():
    return np.mean((Hypothesis(x_input) - labels)**2)

# %% [markdown]
# ## Gradient
# >### $\frac{\partial}{\partial w}cost(w, b) = \frac{1}{m}  \sum_{i=1}^{m}(x_{i}(x_{i}w+(b-y_{i})))$
# >### $\frac{\partial}{\partial b}cost(w, b) = \frac{1}{m}  \sum_{i=1}^{m}(x_{i}w - y_{i} + b)$

# %%
# Gradient
def Gradient(x, y):
    return np.mean(x*(x*W+(B-y))), np.mean((W*x-y+B))

# %% [markdown]
# ## Training
# >### $\mu$ : Learning rate
# >### $w = w - \mu\frac{\partial}{\partial w}cost(w, b)$
# >### $b = b - \mu\frac{\partial}{\partial b}cost(w, b)$

# %%
# %%time
# Parameter Set
# epochs = 100
# learning_rate = 0.01
epochs = 200000          # learning_rate 값 변경에 따라 조정해야 할 수 있음
learning_rate = 0.0005  # 값을 줄여가면서 실험 0.005, 0.001, 0.0005, 0.0003 ..

# 학습 (Training)
for cnt in range(0, epochs+1):
    if cnt % (epochs//20) == 0:
      print("[{:>5}] cost = {:>10.4}, W = {:>7.4}, B = {:>7.4}".format(cnt, Cost(), W, B))

    grad_w, grad_b = Gradient(x_input, labels)
    W -= learning_rate * grad_w
    B -= learning_rate * grad_b
# Out:
# [    0] cost =  1.179e+04, W =  0.3454, B =  0.5978
# [10000] cost =      525.8, W =   1.449, B =   47.06
# [20000] cost =      203.4, W =  0.9407, B =   75.15
# [30000] cost =       85.3, W =  0.6328, B =   92.15
# [40000] cost =      42.06, W =  0.4464, B =   102.4
# [50000] cost =      26.22, W =  0.3337, B =   108.7
# [60000] cost =      20.42, W =  0.2654, B =   112.4
# [70000] cost =       18.3, W =  0.2241, B =   114.7
# [80000] cost =      17.52, W =  0.1991, B =   116.1
# [90000] cost =      17.24, W =   0.184, B =   116.9
# [100000] cost =      17.13, W =  0.1749, B =   117.4
# [110000] cost =      17.09, W =  0.1694, B =   117.7
# [120000] cost =      17.08, W =  0.1661, B =   117.9
# [130000] cost =      17.07, W =  0.1641, B =   118.0
# [140000] cost =      17.07, W =  0.1627, B =   118.1
# [150000] cost =      17.07, W =  0.1622, B =   118.1
# [160000] cost =      17.07, W =  0.1622, B =   118.1
# [170000] cost =      17.07, W =  0.1622, B =   118.1
# [180000] cost =      17.07, W =  0.1622, B =   118.1
# [190000] cost =      17.07, W =  0.1622, B =   118.1
# [200000] cost =      17.07, W =  0.1622, B =   118.1
# CPU times: user 5.29 s, sys: 7.03 ms, total: 5.3 s
# Wall time: 5.32 s

# %% [markdown]
# ## Predict

# %%
# Predict
def Predict(x):
    return Hypothesis(x)

age = np.array([50.0])
print("{} Years : {:>7.4}mmHg".format(age[0], Predict(age)[0]))
# Out:
# 50.0 Years :   126.2mmHg
